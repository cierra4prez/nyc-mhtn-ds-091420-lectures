# %% [markdown]
# # Python Libraries 1
#
# _September 16, 2020_
#
# Agenda today:
# - Introduction to Numpy: array math
# - Introduction to Pandas: importing, indexing, and math

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (0.25.3)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.13.3 in /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from pandas) (1.19.1)
# Requirement already satisfied: pytz>=2017.2 in /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from pandas) (2020.1)
# Requirement already satisfied: six>=1.5 in /Users/candaur/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages (from python-dateutil>=2.6.1->pandas) (1.15.0)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Part I. Numpy
# The basic data structure that exist in numpy is called numpy arrays. NP arrays are very similar to python lists. The __difference__ between a python list and a Numpy array is that list can only a mix of data types but array can only contain the same data type.
#
# But what is the benefits of using NumPy array instead of the base python lists?
# - Speed
# - Broadcasting Property

# %%
names_list=['Bob','John','Sally']
names_array=np.char.array(['Bob','John','Sally']) #use numpy.array for numbers and numpy.char.array for strings
print(names_list)
print(names_array)
# Out:
# ['Bob', 'John', 'Sally']
# ['Bob' 'John' 'Sally']

# %%
import time

size_of_seq = 100000

def pure_python_version():
    tic = time.time()
    X = range(size_of_seq)
    Y = range(size_of_seq)
    Z = [X[i] + Y[i] for i in range(len(X)) ]
    toc = time.time()
    return toc - tic

def numpy_version():
    tic = time.time()
    X = np.arange(size_of_seq)
    Y = np.arange(size_of_seq)
    Z = X + Y 
    toc = time.time()
    return toc - tic


t1 = pure_python_version()
t2 = numpy_version()
print("python: " + str(t1), "numpy: "+ str(t2))
print("Numpy is in this example " + str(t1/t2) + " times faster!")
# Out:
# python: 0.058038949966430664 numpy: 0.0010318756103515625
# Numpy is in this example 56.24607208872458 times faster!

# %%
## broadcasting and array math

np.array([2,3,4,6]) * 5
# Out:
# array([10, 15, 20, 30])

# %%
li = [2,3,4,6]
li * 5
# Out:
# [2, 3, 4, 6, 2, 3, 4, 6, 2, 3, 4, 6, 2, 3, 4, 6, 2, 3, 4, 6]

# %%
## simulation with numpy - in normal distribution 
rand = np.random.randn(100000);
plt.hist(rand, bins = 200);

# %% [markdown]
# There are many other wonderous things numpy can do, you will encounter them later in the course of the program.

# %% [markdown]
# ## Part II. Pandas
# Pandas stand for paneled data, and it is the most popular library for data scientists to manipulate, clean, and organize dataset in Python. The most fundamental data structure that exists in Pandas is called **DataFrames**.

# %%
# !ls
# Out:
# Intro_to_libraries_1.ipynb    Statistics_Fundamentals.ipynb
# Notes 091520.ipynb            Untitled.ipynb
# Python_Fundamentals.ipynb     auto-mpg.csv
# README.md

# %%
## importing data and look at optional parameters
df = pd.read_csv('auto-mpg.csv')
df.head()
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
# examine and read the data
df.info
# Out:
# <bound method DataFrame.info of       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin                   car name
# 0            70       1  chevrolet chevelle malibu
# 1            70       1          buick skylark 320
# 2            70       1         plymouth satellite
# 3            70       1              amc rebel sst
# 4            70       1                ford torino
# ..          ...     ...                        ...
# 393          82       1            ford mustang gl
# 394          82       2                  vw pickup
# 395          82       1              dodge rampage
# 396          82       1                ford ranger
# 397          82       1                 chevy s-10
#
# [398 rows x 9 columns]>

# %%
df.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=398, step=1)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name         object
# dtype: object

# %%
# examine the information in this dataframe

# %%
# examine the datatypes of the dataframe

# %%
# talk about series and dataframe 
type(df)

# %%
# series

# %%
# indexing and subsetting 

# index by values (loc and iloc)

# %%
df.head()
#returns first 5 rows
# Out:
#     mpg  cylinders  displacement horsepower  weight  acceleration  model year  \
# 0  18.0          8         307.0        130    3504          12.0          70
# 1  15.0          8         350.0        165    3693          11.5          70
# 2  18.0          8         318.0        150    3436          11.0          70
# 3  16.0          8         304.0        150    3433          12.0          70
# 4  17.0          8         302.0        140    3449          10.5          70
#
#    origin                   car name
# 0       1  chevrolet chevelle malibu
# 1       1          buick skylark 320
# 2       1         plymouth satellite
# 3       1              amc rebel sst
# 4       1                ford torino

# %%
df.loc[1,'horsepower']
#specifying row name,1, and column name, 'horsepower'
# Out:
# '165'

# %%
df.loc[4, 'car name']
# Out:
# 'ford torino'

# %%
df.iloc[4,8]
# Out:
# 'ford torino'

# %%
#2nd - 10th row, first 3 columns
df.iloc[2:11, :3]
# Out:
#      mpg  cylinders  displacement
# 2   18.0          8         318.0
# 3   16.0          8         304.0
# 4   17.0          8         302.0
# 5   15.0          8         429.0
# 6   14.0          8         454.0
# 7   14.0          8         440.0
# 8   14.0          8         455.0
# 9   15.0          8         390.0
# 10  15.0          8         383.0

# %%
df.iloc[2:11, :]
#colon gives all columns
# Out:
#      mpg  cylinders  displacement horsepower  weight  acceleration  \
# 2   18.0          8         318.0        150    3436          11.0
# 3   16.0          8         304.0        150    3433          12.0
# 4   17.0          8         302.0        140    3449          10.5
# 5   15.0          8         429.0        198    4341          10.0
# 6   14.0          8         454.0        220    4354           9.0
# 7   14.0          8         440.0        215    4312           8.5
# 8   14.0          8         455.0        225    4425          10.0
# 9   15.0          8         390.0        190    3850           8.5
# 10  15.0          8         383.0        170    3563          10.0
#
#     model year  origin             car name
# 2           70       1   plymouth satellite
# 3           70       1        amc rebel sst
# 4           70       1          ford torino
# 5           70       1     ford galaxie 500
# 6           70       1     chevrolet impala
# 7           70       1    plymouth fury iii
# 8           70       1     pontiac catalina
# 9           70       1   amc ambassador dpl
# 10          70       1  dodge challenger se

# %%
# want weight greater than 3000

# %%
df[df.weight > 3000]
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 364  26.6          8         350.0        105    3725          19.0
# 365  20.2          6         200.0         88    3060          17.1
# 366  17.6          6         225.0         85    3465          16.6
# 374  23.0          4         151.0          ?    3035          20.5
# 387  38.0          6         262.0         85    3015          17.0
#
#      model year  origin                           car name
# 0            70       1          chevrolet chevelle malibu
# 1            70       1                  buick skylark 320
# 2            70       1                 plymouth satellite
# 3            70       1                      amc rebel sst
# 4            70       1                        ford torino
# ..          ...     ...                                ...
# 364          81       1              oldsmobile cutlass ls
# 365          81       1                    ford granada gl
# 366          81       1             chrysler lebaron salon
# 374          82       1                     amc concord dl
# 387          82       1  oldsmobile cutlass ciera (diesel)
#
# [168 rows x 9 columns]

# %%
df.weight > 3000
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 393    False
# 394    False
# 395    False
# 396    False
# 397    False
# Name: weight, Length: 398, dtype: bool

# %%
#df[''] - use when there's a space in columb name
#df. - this is called subsetting

# %%
# examine whether we have missing value - it could really affect the data!
df.isnull().sum()

# %%
# exercise - want weight greater than 3000 and mpg less than 18 
weight_greater_3000 = df[df.weight > 3000]

# %%
df[df.weight > 3000]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 1    15.0          8         350.0         165    3693          11.5
# 2    18.0          8         318.0         150    3436          11.0
# 3    16.0          8         304.0         150    3433          12.0
# 4    17.0          8         302.0         140    3449          10.5
# ..    ...        ...           ...         ...     ...           ...
# 364  26.6          8         350.0         105    3725          19.0
# 365  20.2          6         200.0          88    3060          17.1
# 366  17.6          6         225.0          85    3465          16.6
# 374  23.0          4         151.0           0    3035          20.5
# 387  38.0          6         262.0          85    3015          17.0
#
#      model year  origin                           car name
# 0            70       1          chevrolet chevelle malibu
# 1            70       1                  buick skylark 320
# 2            70       1                 plymouth satellite
# 3            70       1                      amc rebel sst
# 4            70       1                        ford torino
# ..          ...     ...                                ...
# 364          81       1              oldsmobile cutlass ls
# 365          81       1                    ford granada gl
# 366          81       1             chrysler lebaron salon
# 374          82       1                     amc concord dl
# 387          82       1  oldsmobile cutlass ciera (diesel)
#
# [168 rows x 9 columns]

# %%
##with group
# exercise - get the cars that are heavier than 3000 but has a horsepower less than 150 
wght_over3000_hp_under150 = df[(df.weight > 3000)&(df.horsepower<150)]
# should be 150 cars that satisfy the criteria

# %%
df = df.replace("?",0)
df['horsepower'] = df.horsepower.astype('int')
df[(df.weight > 3000) & (df.horsepower < 150)]
#runs through everything
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0    18.0          8         307.0         130    3504          12.0
# 4    17.0          8         302.0         140    3449          10.5
# 34   16.0          6         225.0         105    3439          15.5
# 35   17.0          6         250.0         100    3329          15.5
# 36   19.0          6         250.0          88    3302          15.5
# ..    ...        ...           ...         ...     ...           ...
# 364  26.6          8         350.0         105    3725          19.0
# 365  20.2          6         200.0          88    3060          17.1
# 366  17.6          6         225.0          85    3465          16.6
# 374  23.0          4         151.0           0    3035          20.5
# 387  38.0          6         262.0          85    3015          17.0
#
#      model year  origin                           car name
# 0            70       1          chevrolet chevelle malibu
# 4            70       1                        ford torino
# 34           71       1          plymouth satellite custom
# 35           71       1          chevrolet chevelle malibu
# 36           71       1                    ford torino 500
# ..          ...     ...                                ...
# 364          81       1              oldsmobile cutlass ls
# 365          81       1                    ford granada gl
# 366          81       1             chrysler lebaron salon
# 374          82       1                     amc concord dl
# 387          82       1  oldsmobile cutlass ciera (diesel)
#
# [101 rows x 9 columns]

# %%
## with fangfang
wght_over3000_hp_under150 = df[(df.weight > 3000)&(df.horsepower<150)]

# %%
# seems like we have a problem! Can we try to debug this?

# %%
# get rid of anomaly

# %%
# exercise - get a list of car name where the mpg is less than 18 and weight is greater than 3500
df[(df.weight > 3000) & (df.mpg < 18)]
##use parentheses to follow order of operation
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 1    15.0          8         350.0        165    3693          11.5
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# 5    15.0          8         429.0        198    4341          10.0
# 6    14.0          8         454.0        220    4354           9.0
# ..    ...        ...           ...        ...     ...           ...
# 286  17.6          8         302.0        129    3725          13.4
# 287  16.5          8         351.0        138    3955          13.2
# 289  16.9          8         350.0        155    4360          14.9
# 290  15.5          8         351.0        142    4054          14.3
# 366  17.6          6         225.0         85    3465          16.6
#
#      model year  origin                  car name
# 1            70       1         buick skylark 320
# 3            70       1             amc rebel sst
# 4            70       1               ford torino
# 5            70       1          ford galaxie 500
# 6            70       1          chevrolet impala
# ..          ...     ...                       ...
# 286          79       1           ford ltd landau
# 287          79       1     mercury grand marquis
# 289          79       1   buick estate wagon (sw)
# 290          79       1  ford country squire (sw)
# 366          81       1    chrysler lebaron salon
#
# [107 rows x 9 columns]

# %%
# exercise - get a list of car name where the mpg is less than 18 and weight is greater than 3500

df[(df.mpg < 18) & (df.weight > 3500)]
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 1    15.0          8         350.0         165    3693          11.5
# 5    15.0          8         429.0         198    4341          10.0
# 6    14.0          8         454.0         220    4354           9.0
# 7    14.0          8         440.0         215    4312           8.5
# 8    14.0          8         455.0         225    4425          10.0
# ..    ...        ...           ...         ...     ...           ...
# 285  17.0          8         305.0         130    3840          15.4
# 286  17.6          8         302.0         129    3725          13.4
# 287  16.5          8         351.0         138    3955          13.2
# 289  16.9          8         350.0         155    4360          14.9
# 290  15.5          8         351.0         142    4054          14.3
#
#      model year  origin                   car name
# 1            70       1          buick skylark 320
# 5            70       1           ford galaxie 500
# 6            70       1           chevrolet impala
# 7            70       1          plymouth fury iii
# 8            70       1           pontiac catalina
# ..          ...     ...                        ...
# 285          79       1  chevrolet caprice classic
# 286          79       1            ford ltd landau
# 287          79       1      mercury grand marquis
# 289          79       1    buick estate wagon (sw)
# 290          79       1   ford country squire (sw)
#
# [91 rows x 9 columns]
